# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
from utils.mat_op import sum_chunk

# %%
data = loadmat('./data/n10612_6_230423_t162213_C.mat')

# %%
plt.imshow(data["data"])

# %%
plt.plot(data["data"][0,: ])

# %%
# %%timeit
sum_chunk(input).shape
# Out:
# 8.39 ms ± 302 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
x = sum_chunk(input, 50)

# %%
plt.imshow(x)

# %%
input.shape
# Out:
# (60, 5362)

# %%
data["data"].reshape(-1, 3).shape
# Out:
# (107240, 3)

# %%
cont[:,1]
# Out:
# (60,)

# %%
plt.imshow(method6(input, cont))

# %%
cont.shape
# Out:
# (60, 1340)

# %%
data["data"].shape[1] // 4
# Out:
# 1340
