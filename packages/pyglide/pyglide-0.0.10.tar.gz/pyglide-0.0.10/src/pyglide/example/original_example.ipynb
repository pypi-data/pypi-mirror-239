# %% [markdown]
# # Developing Data Products
# ### Presented by Brian Caffo
# ### Date: 06/15/2023

# %% [markdown]
# Hello everyone, my name is Brian Caffo and I am excited to welcome you to the Developing Data Products course. This course is designed to provide you with the necessary tools for improving the data analysis process and making data-driven decisions.
#
# We are excited about the opportunity to attempt to scale Data Science education. We intend for the courses to be self-contained, fast-paced, and interactive. Thank you for joining us, and we look forward to seeing you in class!

# %% [markdown]
# ## Shiny Application

# %% [markdown]
# - Shiny Part 1
# - Shiny Part 2
# - Shiny Part 3

# %% [markdown]
# In part 1, we will introduce Shiny, which is the cornerstone of this course and we will be using it to develop data products.
# In part 2, we’ll delve into the fascinating world of reactive expressions.
# In part 3, we’ll discuss how to use ShinyUiEditor to create a user interface for your Shiny application. Finally, we’ll discuss how to deploy your Shiny application on the web.

# %% [markdown]
# Provide an example where Shiny can be used to improve the data analysis process.
#
# <div><!--Course_Text--></div>

# %% [markdown]
# In this week’s assignment, you will create a linear regression model in Python (generate the data using random numbers).
#
# <div><!--Course_Code--> </div>
